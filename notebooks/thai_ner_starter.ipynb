# %% [markdown]
# # Thai Public Person NER Project (Starter Notebook)
#
# This notebook helps you:
# - Load Thai NER dataset
# - Explore labels
# - Prepare for training

# %%
# Install dependencies
# !pip install -q datasets transformers evaluate seqeval pythainlp pandas scikit-learn

# %%
# Load datasets
from datasets import load_dataset

ner_dataset = load_dataset("pythainlp/thainer-corpus-v2.2")
sent_dataset = load_dataset("pythainlp/wisesight_sentiment")

print(ner_dataset)
print(sent_dataset)

# %%
# Explore NER dataset sample
sample = ner_dataset['train'][0]
print(sample)

# %%
# Check label names
features = ner_dataset['train'].features
label_list = features['ner_tags'].feature.names
print(label_list)

# %% [markdown]
# Next Steps:
# - Map labels to PERSON / PUBLIC_PERSON
# - Prepare token classification model
# - Fine-tune WangchanBERTa
